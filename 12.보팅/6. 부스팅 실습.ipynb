# %% [markdown]
# #1. 파일 읽기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

filepath = '/content/drive/MyDrive/8. 의사결정트리/data/features_dup.txt'
df = pd.read_csv(filepath, header=None, names=['index', 'name'])
df.head()

# %%
file_path = '/content/drive/MyDrive/8. 의사결정트리/data/'
X_train = pd.read_csv(file_path+'train/X_train.txt', sep='\s+', header=None, names=df.name)
y_train = pd.read_csv(file_path+'train/y_train.txt', sep='\s+', header=None, names=['action'])

X_test = pd.read_csv(file_path+'test/X_test.txt', sep='\s+', header=None, names=df.name)
y_test = pd.read_csv(file_path+'test/y_test.txt', sep='\s+', header=None, names=['action'])

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 561 entries, tBodyAcc-mean()-X to angle(Z,gravityMean)
# dtypes: float64(561)
# memory usage: 31.5 MB

# %% [markdown]
# #2. 모델 만들기

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import time

# time.time()은 현재 시간을 얻게 된다.
# 모델의 학습 시간을 알기 위해 시작 시간을 현재 시간으로 설정한다.
start_time = time.time()

gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_train, y_train)
# 모델의 학습 시간을 알기 위해 끝 시간을 현재 시간으로 설정한다.
end_time = time.time()
# 모델 생성 이후 값을 예측하기 위해 사용되는 부분으로 학습 시간에서는 배제되어야 한다.
pred = gb_clf.predict(X_test)

print('정확도 : ', accuracy_score(y_test, pred))
print('수행 시간 : ', end_time - start_time)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:1454: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 정확도 :  0.9389209365456397
# 수행 시간 :  756.4511666297913

# %% [markdown]
# #3. 하이퍼 파라미터

# %%
from sklearn.model_selection import GridSearchCV

gb_clf = GradientBoostingClassifier()

def get_best_hyper_paramerter():
  params =  {
     'n_estimators':n_estimators_list, 
     'learning_rate':learning_rate_list
  }

  grid_cv = GridSearchCV(gb_clf, param_grid=params, scoring='accuracy', cv=2)
  grid_cv.fit(X_train, y_train.values.reshape(-1))
  print('Best Score: ', grid_cv.best_score_)
  print('Best Hyper Parameter: ', grid_cv.best_params_)

# %%
n_estimators_list = [100]
learning_rate_list = [0.05]

get_best_hyper_paramerter()
# Out:
# Best Score:  0.8989390642002176
# Best Hyper Parameter:  {'learning_rate': 0.05, 'n_estimators': 100}

# %%
n_estimators_list = [500]
learning_rate_list = [0.05]

get_best_hyper_paramerter()

# %%
n_estimators_list = [100]
learning_rate_list = [0.1]

get_best_hyper_paramerter()
